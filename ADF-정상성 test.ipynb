# %% [markdown]
# <a href="https://colab.research.google.com/github/cras-lab/Finance1/blob/main/ADF-%EC%A0%95%EC%83%81%EC%84%B1%20test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 필요한 모듈을 임포트 한다.

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller, kpss
import yfinance as yf

# %% [markdown]
# Yahoo finance에서 삼성전자 주가를 읽어온다.

# %%
symbol = '005930.KS' # 삼성전자
df = yf.download( symbol, start='2020-01-01', end='2020-12-31',  progress=False)

# %% [markdown]
# 삼성전자 주가를 도식화 해 본다.

# %%
df.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ADF 검정의 p-값을 구해 본다.

# %%
result1 = pd.Series( adfuller(df.Close)[0:4] )
print("p값=", result1[1], " 임계치=", result1[0])
# Out:
# p값= 0.9938424573664312  임계치= 0.9614829595737703

# %% [markdown]
# 이제 수익률을 도식화 해본다.

# %%
pct = df.Close.pct_change().fillna(0)
pct.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# 수익률의 ADF-검정을 하고 p값을 구해 본다.

# %%
result2 = pd.Series( adfuller(pct)[0:4] )
print("p값=", result2[1], " 임계치=", result2[0])
# Out:
# p값= 3.1251820310201834e-17  임계치= -9.913425485741499
